# %% [markdown]
# **TASK #00**
#
# **Name : Abhishek Dey**\
#  **Reg.: 2017331021**

# %% [markdown]
# **Signal-01 : Signals and Plotting the signal.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
t = np.linspace(0, 2.0, 100)

# %% [markdown]
# A Simple sinusoidal signal can be expressed as the following.
#
# ***Y(t) = Asin(2πft+phase)***

# %%
def createsignal(A,f,phase):

  y = A*np.sin( 2 * np.pi * f * t + phase )

  return y

# %% [markdown]
# **Create sinusoidal signal and plot the signal**

# %%
y = createsignal(1,1,-np.pi)


fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
fig.suptitle('Different subplots of a sinusoidal signal', fontsize=20)

ax[0, 0].plot(t,y)
ax[0, 0].set_title('continuous signal', fontsize = 15)

ax[0, 1].stem(t,y)
ax[0, 1].set_title('stem signal', fontsize = 15)

ax[1,0].scatter(t,y)
ax[1,0].set_title('scatter signal', fontsize = 15)
ax[-1,-1].axis('off')
plt.show()




y = createsignal(1,200,(np.pi)/3)


fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
fig.suptitle('Different subplots of a second sinusoidal signal', fontsize=20)

ax[0, 0].plot(t,y)
ax[0, 0].set_title('continuous signal', fontsize = 15)

ax[0, 1].stem(t,y)
ax[0, 1].set_title('stem signal', fontsize = 15)

ax[1,0].scatter(t,y)
ax[1,0].set_title('scatter signal', fontsize = 15)
ax[-1,-1].axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# **Three different sinusoidal signals are plot below and then combined plot is also shown**

# %%
y1 = createsignal(2,5,0)

y2 = createsignal(1,3,-np.pi)

y3 = createsignal(3,1,0)

y4 = createsignal(5,7,0)



fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('3 Sinusoidal signal and a combined signal', fontsize=15)

ax[0, 0].plot(t,y1, 'r')
ax[0, 0].set_title('y1(t)', fontsize = 15)

ax[0, 1].plot(t,y2, 'g')
ax[0, 1].set_title('y2(t)', fontsize = 15)

ax[1,0].plot(t,y3, 'b')
ax[1,0].set_title('y3(t)', fontsize = 15)

ax[1,1].plot(t,y4,)
ax[1,1].set_title('y4(t)', fontsize = 15)

ax[2,0].plot(t, y1 + y2 + y3 + y4)
ax[2,0].set_title('y(t) = y1(t) + y2(t) + y3(t) + y4(t)', fontsize = 15)

ax[-1,-1].axis('off')
plt.show()

# %% [markdown]
# **Signal-02: Basic Properties of a Signal.**

# %%
t = np.arange(0,2.0,.001)

# %%
def createsignal2(t,A,f,phase):

  y = A*np.sin( 2 * np.pi * f * t + phase )

  return y

# %% [markdown]
# Create some signals with the createsignal2 function and plot them.

# %%
y1 = createsignal2(t,1,4,0)

y2 = createsignal2(t,3,10,-np.pi)

y3 = createsignal2(t,4,20,(np.pi)/6)

y = y1 + y2 + y3

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))

fig.suptitle('Below is the representation of 3 signals and their composite signal', fontsize = 15)

ax[0,0].plot(t,y1)
ax[0,0].set_title('y1',fontsize = 15)

ax[0,1].plot(t,y2)
ax[0,1].set_title('y2',fontsize = 15)

ax[1,0].plot(t,y3)
ax[1,0].set_title('y3',fontsize = 15)

ax[1,1].plot(t,y)
ax[1,1].set_title('composite signal y = y1 + y2 + y3', fontsize = 15)

plt.show()

# %% [markdown]
# **Lets sample the signals based on some sampling frequency fs**

# %%
fs = 15

steps = 1.0/fs 

n = np.arange(0,2.0,steps)

y = createsignal2(n, 1, 5, 0) + createsignal2(n, 2, 10, -np.pi) + createsignal2(n, 1, 15, 0)
plt.title('fs = 15', fontsize = 15)
plt.stem(n,y)
plt.show()


fs = 20

steps = 1.0/fs 

n = np.arange(0,2.0,steps)

y = createsignal2(n, 1, 5, 0) + createsignal2(n, 2, 10, -np.pi) + createsignal2(n, 1, 15, 0)
plt.title('fs = 20', fontsize = 15)
plt.stem(n,y)
plt.show()

fs = 25

steps = 1.0/fs 

n = np.arange(0,2.0,steps)

y = createsignal2(n, 1, 5, 0) + createsignal2(n, 2, 10, -np.pi) + createsignal2(n, 1, 15, 0)
plt.title('fs = 25', fontsize = 15)
plt.stem(n,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %% [markdown]
# **Task #01**\
# **Name: Abhishek Dey**\
# **Reg.:2017331021** \
#
#
# \
# \
# ***The task is to simulate analogue to digital signal using pulse code modulation or known as PCM technic.***\
#
# The process has mainly three steps namely:
#
# 1.Sampling of the signal\
# 2.Quantization of the sampled signal\
# 3.coverting the quantized value as streams of bits.
#
# thus,an analogue signal is converted to a digital signal.

# %% [markdown]
# lets at first generate and plot the analogue signal.
#
# **y(t) = Asin(2πft)**

# %%
t = np.arange(0,2.0,.001)

# %%
def createsignal(A,f):

  y = A*np.sin( 2 * np.pi * f * t )

  return y

# %%
y = createsignal(6,2)

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
fig.suptitle('Different subplots of sinusoidal signal', fontsize=20)

ax[0, 0].plot(t,y)
ax[0, 0].set_title('continuous signal', fontsize = 15)

ax[0, 1].stem(t,y)
ax[0, 1].set_title('stem signal', fontsize = 15)

ax[1,0].axis('off')
ax[1,1].axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if __name__ == '__main__':

# %% [markdown]
# **Step1: Sampling**\
# Let ,\
#  n be the number of samples per interval.\
# fs be the sampling frequency.

# %%
def create_sample_signal(t,A,f):

  y = A*np.sin( 2 * np.pi * f * t )

  return y

# %%
fs = 25

steps = 1.0/fs 

n = np.arange(0,2.0,steps)

ys = create_sample_signal(n, 6, 2)

plt.title(' The sampled analogue signal at fs = 15', fontsize = 15)
plt.stem(n,ys)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# **Step2: Quantization**
#
# we have to perfrom the following :
#
# 1.we have to partition the signal value with height delta of L number of levels.between Max amplitude and Min amplitude.
#
# 2.Decrease the partition value by delta/2 .(codebook)
#
# 3.Assign every codebook interval the corresponding partition number or the quantized values.
#
# lets,consider the number of bits per level = 3 ,so the total number of levels would be pow(2,3)= 8.

# %%
n_bits = 3
L = 2 ** n_bits

A = 6

mx = A
mn = -A 

delta  = (mx-mn)/L 

prtion = np.arange(mn,mx,delta)

cdbook = np.arange(mn-(delta/2),mx+(delta/2),delta)

yq = np.copy(ys)

encode = np.copy(ys)

for i in range(len(prtion)):
  l = cdbook[i]
  r = cdbook[i + 1]
  for j in range(len(ys)):
   
    if(i != len(prtion) - 1 and l <= ys[j] and ys[j] < r):
      yq[j] = prtion[i]
      encode[j] = i
   
    if(i == len(prtion) - 1 and l <= ys[j]):
      yq[j] = prtion[i]
      encode[j] = i


for i in range(len(yq)):
    yq[i] = yq[i] + (delta / 2) 

plt.title(' The sampled analogue signal at fs = 15', fontsize = 15)
plt.stem(n,ys)
plt.show()


plt.title(' The sampled  & quantized analogue signal', fontsize = 15)
plt.stem(n,yq)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# **Step3: Encoding**
#
# we have to perform the following
#
# 1.Convert the assigned decimal codec to the binary codec.\
# 2.Append all the binary codec into an array of 0 and 1.\
# 2.plot a step graph

# %%
def decimalToBinary(val, bit):
    binary = "{0:b}".format(int(val))
    if(len(binary) > bit):
      return binary
    extra_zero = bit - len(binary)
    return extra_zero * "0" + binary

# %%
binary_codec = []
for i in range(len(encode)):
  binary = decimalToBinary(encode[i], n_bits)
  for j in range(len(binary)):
    binary_codec.append(binary[j])

pos = np.arange(len(binary_codec))


plt.figure(figsize=(20, 5))
plt.title('The digital signal', fontsize = 15)

plt.ylim(-1, 3)
plt.step(pos, binary_codec)

plt.show()

# %% [markdown]
# **Task #02**
#
# **Name: Abhishek Dey**\
# **Reg.: 2017331021**
#
# ***The task is to simulate digital-digital conversion using different technics such as Line coding,Block coding ***

# %% [markdown]
# **Line codung -> Unipolar NRZ**

# %%
bits = np.array([0,1,0,1,0,1,1,1,0,0,1,0,1,0,1]) 
time = 10e-4   
bit_rate = 1/time  
Fs = 4*bit_rate    
N = len(bits)   
T = np.linspace(0,time,80)
x = np.array([])
for i in range(N):
  tmp = bits[i]* np.ones(len(T))
  x = np.append(x, tmp)
t = np.linspace(0,N*time,len(x))

plt.figure(figsize=(20, 5))
plt.plot(t, x)
plt.show()

# %% [markdown]
# **Line coding -> NRZ-I**

# %%
bits = np.array([0,1,0,1,0,1,1,1,0,0,1,0,1,0,1]) 
time = 10e-4   
bit_rate = 1/time  
Fs = 4*bit_rate    
N = len(bits)   
T = np.linspace(0,time, 100)

x = np.array([])
last_bit = 1
for i in range(N):
  if bits[i] == 1:
    temp = (-1) * last_bit * np.ones(len(T))
    last_bit = -last_bit
  else:
    temp = last_bit * np.ones(len(T))
  x = np.append(x, temp)
t = np.linspace(0,N*time,len(x))
plt.figure(figsize=(20, 5))
plt.plot(t, x)
plt.show()

# %% [markdown]
# **Line coding -> NRZ-L**

# %%
bits = np.array([0,1,0,1,0,1,1,1,0,0,1,0,1,0,1]) 
time = 10e-4   
bit_rate = 1/time  
Fs = 4*bit_rate    
N = len(bits)   
T = np.linspace(0,time, 100)

x = np.array([])
last_bit = 1
for i in range(N):
  if bits[i] == 1:
    temp = (-1) * last_bit * np.ones(len(T))
    
  else:
    temp = last_bit * np.ones(len(T))
  x = np.append(x, temp)
t = np.linspace(0,N*time,len(x))
plt.figure(figsize=(20, 5))
plt.plot(t, x)
plt.show()

# %% [markdown]
# **Task #03**
#
# **Name: Abhishek Dey**\
# **Reg.:2017331021**
#
# ***The task is to simulate digital-analogue conversion such as ASK,RSK,PSK***

# %% [markdown]
# **Amplitude shift keying(ASK)->**

# %%
bits = np.array([0,1,0,1,0,1,1,1,0,0,1,0,1,0,1]) 
time = 10e-4   
bit_rate = 1/time  
Fs = 4*bit_rate    
N = len(bits)   
T = np.linspace(0,time,80)
x = np.array([])
for i in range(N):
  tmp = bits[i]* np.ones(len(T))
  x = np.append(x, tmp)
t = np.linspace(0,N*time,len(x))
plt.figure(figsize=(20, 5))
plt.plot(t, x)
plt.show()

# %% [markdown]
# **generating carrier signal**

# %%
A = 4  
time = 10e-4   
T = np.linspace(0,time,80)
f =round(5*bit_rate)
t = np.linspace(0,N*time,len(x))
yc = A * np.sin(2.0 * np.pi * f * t)
plt.figure(figsize=(20, 5))
plt.title('Carrier signal',fontsize = 15)
plt.plot(t,yc)
plt.show()

# %% [markdown]
# **The combined signal would be->**

# %%
y = yc * x 

plt.figure(figsize=(20, 5))
plt.title('ASK modulated signal',fontsize = 15)
plt.plot(t,y)
plt.show()

# %% [markdown]
# **Frequnecy Shift Keying (FSK)->**

# %%
def uNRZ(bits, N, bit_rate, T, Time):
  
  x = np.array([])
  for i in range(N):
    temp = bits[i]* np.ones((T))
    x = np.append(x, temp)
  t = np.linspace(0,N*Time,len(x))
  return [t, x]

# %%
bits = np.array([0,1,0,1,0,1,1,1,0,0,1,0,1,0,1])
Time = 10e-6   
bit_rate = 1/Time 
N = len(bits)   
T = 100
t,x = uNRZ(bits, N, bit_rate, T, Time)

plt.figure(figsize=(20, 5))
plt.plot(t,x)
plt.show()

# %% [markdown]
# **Assiging carrieer signal two different frequencies.One for 0 and another for 1 and genertaing the FSK modulated signal.**

# %%
A = 5                      
fc1 =round(10*bit_rate)
fc2 =round(25*bit_rate)
tc = np.arange(0, Time, Time/T)
fsk = np.array([])
for i in range(N):
  if bits[i] == 1:
    sig = A * np.sin(2.0 * np.pi * fc1 * tc)
    fsk = np.append(fsk, sig)
  else:
    sig = A * np.sin(2.0 * np.pi * fc2 * tc)
    fsk = np.append(fsk, sig)

plt.figure(figsize=(20, 5))
plt.title('FSK modulated signal',fontsize = 15)
plt.plot(t,fsk)
plt.show()

# %% [markdown]
# **Phase Shift keying (PSK)->**
#
# *Here we use phase 0 for 0 and phase 180 for 1*

# %%
bits = np.array([0,1,0,1,0,1,1,1,0,0,1,0,1,0,1])
Time = 10e-6   
bit_rate = 1/Time 
N = len(bits)   
T = 100
t,x = uNRZ(bits, N, bit_rate, T, Time)
plot_signal(t, x)

# %% [markdown]
# *Below is the PSK modulated signal*

# %%
A = 5                     
fc =round(10*bit_rate)
ph1 = 0
ph2 = np.pi
tc = np.arange(0, Time, Time/T)
psk = np.array([])
for i in range(N):
  if bits[i] == 1:
    sig = A * np.sin((2.0 * np.pi * fc * tc) + ph2)
    psk = np.append(psk, sig)
  else:
    sig = A * np.sin((2.0 * np.pi * fc * tc) + ph1)
    psk = np.append(psk, sig)

plt.figure(figsize=(20, 5))
plt.title('PSK modulated signal',fontsize = 15)
plt.plot(t,psk)
plt.show()

# %% [markdown]
# **Task #04**\
# **Name: Abhishek Dey**\
# **Reg.:2017331021**
#
# ***The task is to simulate analog-analog conversion using FM,AM,PM***

# %% [markdown]
# **Frequnecy MOdulation(FM)->**

# %%
Ac=5; 
fc=30; 
t=np.arange(0, 2.0, 0.001)
xc=Ac*np.cos(2*np.pi*fc*t); 
plt.figure(figsize=(20, 5))
plt.title('Carrier signal',fontsize = 15)
plt.plot(t,xc)
plt.show()

# %%
mdindex = 1.
fm=5
xm=np.sin((2*np.pi*fm*t))
plt.figure(figsize=(20, 5))
plt.title('Modulating signal',fontsize = 15)
plt.plot(t,xm)
plt.show()

# %% [markdown]
# FM can be calculated using the formula $$y(t) = A_{c}cos(2{\pi}[f_{c}t+ mdindex*sin(2{\pi}f_{m}t)]) $$

# %%
y = Ac*np.cos(2. * np.pi * (fc * t + mdindex * np.sin(2*np.pi*fm*t)))
plt.figure(figsize=(20, 5))
plt.title('FM modulated signal',fontsize = 15)
plt.plot(t,y)
plt.show()

# %% [markdown]
# **Amplitude Modulation(AM)->**

# %%
A=5; 
fc=1; 
t=np.arange(0, 30, 0.1)
yc=A*np.sin(2*np.pi*fc*t); 
plt.figure(figsize=(20, 5))
plt.title('Carrier signal',fontsize = 15)
plt.plot(t,yc)
plt.show()

# %%
m = 1.0
A = 5
M = A * m
fm = .05
ym=M*np.cos((2*np.pi*fm*t))

plt.figure(figsize=(20, 5))
plt.title('Message signal',fontsize = 15)
plt.plot(t,ym)
plt.show()

# %% [markdown]
# Amplitude modulation can be calculated by this formula $$y(t) = [1 + mcos(2{\pi}f_{m}t+{\phi})]*Asin(2{\pi}f_{c}t)$$

# %%
y=(1+m*np.cos((2*np.pi*fm*t)))*A*np.sin(2*np.pi*fc*t)
plt.figure(figsize=(20, 5))
plt.title('AM modulated signal',fontsize = 15)
plt.plot(t,y)
plt.show()

# %% [markdown]
# **Phase Modulation(PM)->**

# %%
Ac=5; 
fc=2; 
t=np.arange(0, 2.0, 0.0001)
yc=Ac*np.sin(2*np.pi*fc*t); 
plt.figure(figsize=(20, 5))
plt.title('Carrier signal',fontsize = 15)
plt.plot(t,yc)
plt.show()

# %%
k = 1.0
fm = 2
Am = 3
phase  = 180
ym=Am*np.sin(2 * np.pi*fm*t+phase)
plt.figure(figsize=(20, 5))
plt.title('Modulating signal',fontsize = 15)
plt.plot(t,ym)
plt.show()

# %% [markdown]
# **Phase modulation can be calculated using the formula $$y(t) = A_{c}sin(2{\pi}f_{c}t+ km(t) +{\phi_{c}})   $$**

# %%
y=Ac*np.sin((2*np.pi*fc*t) + (k * ym + phase))

plt.figure(figsize=(20, 5))
plt.title('PM Modulated Signal',fontsize = 15)
plt.plot(t,y)
plt.show()

# %% [markdown]
# **Task #05**\
# **Name: Abhishek Dey**\
# **Reg.: 2017331021**
#
# ***The task is to run the code in the given link https://inst.eecs.berkeley.edu/~ee123/sp15/lab/lab6/Pre-Lab6-Intro-to-Digital-Communications.html***

# %%
# %pylab
# Import functions and libraries
import numpy as np
import matplotlib.pyplot as plt
#import pyaudio
#import Queue
import threading,time
import sys

from numpy import pi
from numpy import sin
from numpy import zeros
from numpy import r_
from scipy import signal
from scipy import integrate

import threading,time
import multiprocessing

#from rtlsdr import RtlSdr
from numpy import mean
from numpy import power
from numpy.fft import fft
from numpy.fft import fftshift
from numpy.fft import ifft
from numpy.fft import ifftshift
#import bitarray
from  scipy.io.wavfile import read as wavread


# %matplotlib inline
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['fft', 'time', 'f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# Plot an image of the spectrogram y, with the axis labeled with time tl,
# and frequency fl
#
# t_range -- time axis label, nt samples
# f_range -- frequency axis label, nf samples
# y -- spectrogram, nf by nt array
# dbf -- Dynamic range of the spect

def sg_plot( t_range, f_range, y, dbf = 60) :
    eps = 1e-3
    
    # find maximum
    y_max = abs(y).max()
    
    # compute 20*log magnitude, scaled to the max
    y_log = 20.0 * np.log10( abs( y ) / y_max + eps )
    
    fig=figure(figsize=(15,6))
    
    plt.imshow( np.flipud( 64.0*(y_log + dbf)/dbf ), extent= t_range  + f_range ,cmap=plt.cm.gray, aspect='auto')
    plt.xlabel('Time, s')
    plt.ylabel('Frequency, Hz')
    plt.tight_layout()


def myspectrogram_hann_ovlp(x, m, fs, fc,dbf = 60):
    # Plot the spectrogram of x.
    # First take the original signal x and split it into blocks of length m
    # This corresponds to using a rectangular window %
    
    
    isreal_bool = isreal(x).all()
    
    # pad x up to a multiple of m 
    lx = len(x);
    nt = (lx + m - 1) // m
    x = append(x,zeros(-lx+nt*m))
    x = x.reshape((m//2,nt*2), order='F')
    x = concatenate((x,x),axis=0)
    x = x.reshape((m*nt*2,1),order='F')
    x = x[r_[m//2:len(x),ones(m//2)*(len(x)-1)].astype(int)].reshape((m,nt*2),order='F')
    
    
    xmw = x * hanning(m)[:,None];
    
    
    # frequency index
    t_range = [0.0, lx / fs]
    
    if isreal_bool:
        f_range = [ fc, fs / 2.0 + fc]
        xmf = np.fft.fft(xmw,len(xmw),axis=0)
        sg_plot(t_range, f_range, xmf[0:m//2,:],dbf=dbf)
        print (1)
    else:
        f_range = [-fs / 2.0 + fc, fs / 2.0 + fc]
        xmf = np.fft.fftshift( np.fft.fft( xmw ,len(xmw),axis=0), axes=0 )
        sg_plot(t_range, f_range, xmf,dbf = dbf)
    
    return t_range, f_range, xmf

# %%
fs = 44500  # sampling rate
baud = 300  # symbol rate
Nbits = 10  # number of bits
Ns = fs//baud
N = Nbits * Ns
f0 = 1800
bits = randn(Nbits,1) > 0

# %%
np.random.seed(seed=1)
bits = randn(Nbits,1) > 0
M = np.tile(bits,(1,Ns))
t = r_[0.0:N]/fs
OOK = M.ravel()*sin(2*pi*f0*t)

fig = figure(figsize = (16,4))
plot(t,OOK)
xlabel('time [s]')
title('OOK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))
# Out:
# Text(0.5, 1.0, 'OOK signal of the sequence:[[1 0 0 0 1 0 1 0 1 0]]')

# %%
f = r_[0:N/2.0]/N*fs

OOK_f = (np.fft.fft(OOK))

fig = figure(figsize = (16,4))
plot(f,abs(OOK_f[:len(OOK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of an OOK signal ')
axis((0,4096,0,max(abs(OOK_f))))
# Out:
# (0.0, 4096.0, 0.0, 286.85659582353446)

# %%
imp = zeros(N)
imp[::Ns] = bits.ravel()

h = signal.firwin(Ns*4,1.0/Ns)
imp_sinc = signal.fftconvolve(imp,h,mode='full')
t = r_[0.0:len(imp_sinc)]/fs
OOK_s = imp_sinc*sin(2*pi*f0*t)


fig = figure(figsize = (16,4))
plot(t,OOK_s)
xlabel('time [s]')
title('TBW=4 shaped OOK/ASK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:len(imp_sinc)/2.0]/len(imp_sinc)*fs
OOK_sf = (np.fft.fft(OOK_s))

fig = figure(figsize = (16,4))
plot(f,abs(OOK_sf[0:len(OOK_sf)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of an pulse shaped OOK signal ')
axis((0,4096,0,max(abs(OOK_sf))))
# Out:
# (0.0, 4096.0, 0.0, 1.9083193343631832)

# %%
np.random.seed(seed=1)
bits = randn(Nbits,1) > 0 
M = np.tile(bits*2-1,(1,Ns))
t = r_[0.0:N]/fs
BPSK = M.ravel()*sin(2*pi*f0*t)

fig = figure(figsize = (16,4))
plot(t,BPSK)
xlabel('time [s]')
title('BPSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))
# Out:
# Text(0.5, 1.0, 'BPSK signal of the sequence:[[1 0 0 0 1 0 1 0 1 0]]')

# %%
f = r_[0:N/2.0]/N*fs

BPSK_f = (np.fft.fft(BPSK))

fig = figure(figsize = (16,4))
plot(f,abs(BPSK_f[0:len(BPSK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a BPSK signal ')
axis((0,4096,0,max(abs(BPSK_f))))
# Out:
# (0.0, 4096.0, 0.0, 381.4712019091447)

# %%
imp = zeros(N)
imp[::Ns] = bits.ravel()*2-1

h = signal.firwin(Ns*4,1.0/Ns)
imp_sinc = signal.fftconvolve(imp,h,mode='full')
t = r_[0.0:len(imp_sinc)]/fs
BPSK_s = imp_sinc*sin(2*pi*f0*t)


fig = figure(figsize = (16,4))
plot(t,BPSK_s)
xlabel('time [s]')
title('TBW=4 shaped BPSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:len(imp_sinc)/2.0]/len(imp_sinc)*fs
BPSK_sf = (np.fft.fft(BPSK_s))

fig = figure(figsize = (16,4))
plot(f,abs(BPSK_sf[0:len(BPSK_sf)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of a pulse shaped BPSK signal ')
axis((0,4096,0,max(abs(BPSK_sf))))
# Out:
# (0.0, 4096.0, 0.0, 2.0357836385841113)

# %%
#code = { 2: -2+2j, 6: -1+2j, 14: 1+2j, 10: 2+2j,
#        3: -2+1j, 7: -1-1j, 15: 1+1j, 11: 2+1j,
#        1: -2-1j, 5: -1-1j, 13: 1-1j, 9: 2-1j,
#        0: -2-2j, 4: -1-2j, 12: 1-2j, 8: 2-2j}
Nbits = 16  # number of bits
N = Nbits * Ns
code = np.array((-2-2j, -2-1j,-2+2j,-2+1j,-1-2j,-1-1j,-1+2j,-1+1j,+2-2j,+2-1j,+2+2j,+2+1j,1-2j,+1-1j,1+2j,1+1j))/2
np.random.seed(seed=1)
bits = np.int16(rand(Nbits,1)*16) 
M = np.tile(code[bits],(1,Ns))
t = r_[0.0:N]/fs

# these are two ways of producing the same result:
#QAM = (M.real.ravel()*cos(2*pi*f0*t) - M.imag.ravel()*sin(2*pi*f0*t))/2/sqrt(2)
QAM = real(M.ravel()*exp(1j*2*pi*f0*t))/sqrt(2)/2
fig = figure(figsize = (16,4))
plot(t,QAM.real)
xlabel('time [s]')
title("QAM=16 of the sequence:"+ np.array2string(transpose(bits)))
# Out:
# Text(0.5, 1.0, 'QAM=16 of the sequence:[[ 6 11  0  4  2  1  2  5  6  8  6 10  3 14  0 10]]')

# %%
f = r_[0:N/2.0]/N*fs

QAM_f = (np.fft.fft(QAM))

fig = figure(figsize = (16,4))
plot(f,abs(QAM_f[0:len(QAM_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a QAM16 signal ')
axis((0,4096,0,max(abs(QAM_f))))


imp = zeros(N,dtype='complex')
imp[::Ns] = code[bits].ravel()

h = signal.firwin(Ns*4,1.0/Ns)
imp_sinc = signal.fftconvolve(imp,h,mode='full')
t = r_[0.0:len(imp_sinc)]/fs
QAM_s = real(imp_sinc*exp(1j*2*pi*f0*t))


fig = figure(figsize = (16,4))
plot(t,QAM_s)
xlabel('time [s]')
title('TBW=4 shaped QAM16 signal of the sequence:'+ np.array2string(transpose(bits)))
f = r_[0:len(imp_sinc)/2.0]/len(imp_sinc)*fs
QAM_sf = (np.fft.fft(QAM_s))

fig = figure(figsize = (16,4))
plot(f,abs(QAM_sf[0:len(QAM_sf)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of a pulse shaped QAM16 signal ')
axis((0,4096,0,max(abs(QAM_sf))))
# Out:
# (0.0, 4096.0, 0.0, 3.514614508384962)

# %%
np.random.seed(seed=1)
Nbits = 10
N = Nbits * Ns
bits = randn(Nbits,1) > 0 
M = np.tile(bits*2-1,(1,Ns))
delta_f = 600


# compute phase by integrating frequency
ph = 2*pi*cumsum(f0 + M.ravel()*delta_f)/fs
t = r_[0.0:N]/fs
FSK = sin(ph)

fig = figure(figsize = (16,4))
plot(t,FSK)
xlabel('time [s]')
title('FSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))
# Out:
# Text(0.5, 1.0, 'FSK signal of the sequence:[[1 0 0 0 1 0 1 0 1 0]]')

# %%
f = r_[0:N/2.0]/N*fs

FSK_f = (np.fft.fft(FSK))

fig = figure(figsize = (16,4))
plot(f,abs(FSK_f[0:len(FSK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a FSK signal ')
axis((0,4096,0,max(abs(FSK_f))))
# Out:
# (0.0, 4096.0, 0.0, 432.4632482579671)

# %%
delta_f = 150
ph = 2*pi*cumsum(f0 + M.ravel()*delta_f)/fs
t = r_[0.0:N]/fs
MSK = sin(ph)

fig = figure(figsize = (16,4))
plot(t,MSK)
xlabel('time [s]')
title('MSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:N/2.0]/N*fs

MSK_f = (np.fft.fft(MSK))

fig = figure(figsize = (16,4))
plot(f,abs(MSK_f[0:len(MSK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a MSK signal ')
axis((0,4096,0,max(abs(MSK_f))))
tt,ff,xmf = myspectrogram_hann_ovlp(MSK, 148, 44100.0, 0,dbf = 60)
title('Spectrogram of MSK')
# Out:
# 1
# Text(0.5, 1.0, 'Spectrogram of MSK')

# %%
TBW =0.5
Tb = 294
B = Tb*TBW
n = r_[-Tb/2:Tb/2]
h = sqrt(2*pi/log(2))*B/fs*exp(-2*pi*pi*B*B*n*n/fs/fs/log(2))


fig = figure(figsize = (16,4))
plot(h)

freq = signal.fftconvolve(f0 + M.ravel()*delta_f,h)
ph = 2*pi*cumsum(freq)/fs
t = r_[0.0:N]/fs
GMSK = sin(ph)

t = r_[0.0:len(GMSK)]/fs
fig = figure(figsize = (16,4))
plot(t,GMSK)
xlabel('time [s]')
title('GMSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:len(GMSK)/2.0]/len(GMSK)*fs

GMSK_f = (np.fft.fft(GMSK))

fig = figure(figsize = (16,4))
plot(f,abs(GMSK_f[0:len(GMSK_f)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of a GMSK signal ')
axis((0,4096,0,max(abs(GMSK_f))))
tt,ff,xmf = myspectrogram_hann_ovlp(GMSK, 148, 44100.0, 0,dbf = 60)
title('Spectrogram of GMSK')
# Out:
# 1
# Text(0.5, 1.0, 'Spectrogram of GMSK')
